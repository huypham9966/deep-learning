# %%
# %load_ext autoreload
# %autoreload 2 
import sys
for p in sys.path:
    print(p)
# !jupyter kernelspec list
# !pip install sklearn
#!pip install networkx
#!pip install node2vec
import numpy as np
import math as math 
import tensorflow as tf
import graph_synthesis as gs
from random_mini_batches import random_mini_batches3
from random_mini_batches import random_mini_batches2
import networkx as nx
import node2vec as n2v
from sklearn.cluster import KMeans
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# /home/ubuntu/src/cntk/bindings/python
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python36.zip
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/lib-dynload
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/IPython/extensions
# /home/ubuntu/.ipython
# Available kernels:
#   python2           /home/ubuntu/.local/share/jupyter/kernels/python2
#   pyspark3kernel    /home/ubuntu/anaconda3/envs/tensorflow_p36/share/jupyter/kernels/pyspark3kernel
#   pysparkkernel     /home/ubuntu/anaconda3/envs/tensorflow_p36/share/jupyter/kernels/pysparkkernel
#   python3           /home/ubuntu/anaconda3/envs/tensorflow_p36/share/jupyter/kernels/python3
#   sparkkernel       /home/ubuntu/anaconda3/envs/tensorflow_p36/share/jupyter/kernels/sparkkernel
#   sparkrkernel      /home/ubuntu/anaconda3/envs/tensorflow_p36/share/jupyter/kernels/sparkrkernel
# Requirement already satisfied: sklearn in /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages
# Requirement already satisfied: scikit-learn in /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from sklearn)

# %%
class GCN:
    
    def __init__(self, inputdat, labeldat, vertexclass, vertexlabel, testdat, testlabeldat, testvertexclass, testvertexlabel, layer_dims, decayrate = 0.99,
                 l2reg = 1e-2, learning_rate = 0.008, batch_size = 128, epoch_nums = 2000):
        
        #Data
        self.inputdat = inputdat
        self.labeldat = labeldat
        self.vertexdat = vertexlabel
        self.testdat = testdat
        self.testlabeldat = testlabeldat
        self.testvertexdat = testvertexlabel
        self.num_eg = inputdat.shape[0]
        self.inputdim = inputdat.shape[1]
        self.vertexdim = vertexlabel.shape[2]
        self.vertexclass = vertexclass
        self.testvertexclass = testvertexclass
        
        #Hyperparameters
        self.layer_dims = layer_dims
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.epoch_nums = epoch_nums
        self.l2reg = l2reg  
        self.decayrate = decayrate 
        
        #Initialize
        tf.reset_default_graph()
        self.initdata()
        
        #Create graph
        self.output, self.gcn = self.model()
        self.optimizer, self.cost = self.train()
        self.prediction, self.accuracy = self.test()
        self.summary_op = self.create_summaries()
        
        #Run Tensorflow
        config = tf.ConfigProto(allow_soft_placement = True, log_device_placement = True, device_count = {'GPU': 1})
        self.sess = tf.Session(config = config)
        init = tf.group(tf.global_variables_initializer(), tf.local_variables_initializer())
        self.sess.run(init)
        
        #Tensorboard setup
        self.writer = tf.summary.FileWriter('./CNNSave',  (self.sess).graph)
        
        #Train model 
        self.graph_classifier()
        self.prediction_num, self.error_num = self.evaluate("train") 
        #self.evaluate_cluster()
    def  create_summaries(self):
        with tf.name_scope("summaries"):
            tf.summary.scalar("loss", self.cost)
            #tf.summary.scalar("output", self.output)
            tf.summary.scalar("accuracy", self.accuracy)
            tf.summary.histogram("histogram_loss", self.cost)
            #tf.summary.histogram("histogram_loss", self.output)
            summary_op = tf.summary.merge_all()
        return summary_op
    
    def initdata(self):
        self.tflearnrate = tf.placeholder(tf.float32, name = "learnrate")
        self.mode = tf.placeholder(tf.bool, name = "mode")
        self.input = tf.placeholder(tf.float32, shape = [None, self.inputdim, self.inputdim], name = "input")
        self.vertexlabel = tf.placeholder(tf.float32, shape = [None, self.inputdim, self.vertexdim], name = "vertex")
        self.label = tf.placeholder(tf.float32, shape = [None, 1], name = "label")

    
    def model(self):
        layer_dims = self.layer_dims
        layers = {}
        
        inputA = self.input
        inputX = self.vertexlabel
        
        scopegcn = 'GCN'
        with tf.variable_scope(scopegcn):
            #GCN 1 
            #name = 'GCN' + str(1)
            gcn = self.gated_graph_convolutional_layer(inputX, inputA, scopegcn, 20)
        scope = 'batchnorm'+str(0)
        with tf.variable_scope(scope):
            gcn = tf.contrib.layers.batch_norm(gcn, is_training = self.mode, scope = 'batchnorm')
        for i in range(3):
            with tf.variable_scope(scopegcn, reuse = True):
                gcn = self.gated_graph_convolutional_layer(gcn, inputA, scopegcn, 20)
            scope = 'batchnorm'+str(i+1)
            with tf.variable_scope(scope):
                gcn = tf.contrib.layers.batch_norm(gcn, is_training = self.mode, scope = 'batchnorm')
            
        """#GCN 1 
        name = 'GCN' + str(1)
        gcn1 = self.graph_convolutional_layer(inputX, inputA, name, 15) 
        
        #GCN 2 
        name = 'GCN' + str(2)
        gcn2 = self.graph_convolutional_layer(gcn1, inputA, name, 10) 
        
        #GCN 3
        name = 'GCN' + str(3)
        gcn3 = self.graph_convolutional_layer(gcn2, inputA, name, 5)"""
        
        size = gcn.shape[1]
        #print(size)
        pool_flat = gcn[:,size-1,:]
        #pool_flat = tf.reshape(tf.reduce_mean(gcn, axis = 2), [-1, size])
    
        layers[0] = pool_flat
        #Dense layers
        for i in range(len(layer_dims)-1):
            if (i < len(layer_dims) - 2):
                scope = 'denselayers' + str(i+1)
                with tf.variable_scope(scope):
                    layers[i+1] = tf.contrib.layers.fully_connected(num_outputs = layer_dims[i+1], \
                                                        activation_fn = None, inputs = layers[i], scope = 'dense')
                    layers[i+1] = tf.contrib.layers.batch_norm(layers[i+1], is_training = self.mode, scope = 'batchnorm')
                    layers[i+1] = tf.nn.relu(layers[i+1], 'relu')
            else:
                scope = 'denselayers' + str(i+1)
                with tf.variable_scope(scope):
                    layers[len(layer_dims)-1] = tf.layers.dense(units = layer_dims[len(layer_dims)-1], \
                                                    activation = tf.nn.sigmoid, inputs = layers[len(layer_dims)-2])
        
        output = layers[len(layer_dims)-1]
        return output, gcn  
    
    def train(self):
        #Saver for data 
        self.saver = tf.train.Saver()
        self.global_step = tf.Variable(0, dtype = tf.int32, trainable = False, name = 'global_step')
        
        #Define cost 
        gap_loss = tf.reduce_max(self.output) - tf.reduce_min(self.output)
        reg_loss = self.l2reg * sum(tf.nn.l2_loss(tf_var) for tf_var in tf.trainable_variables()) 
        cost = (tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits = self.output, labels = self.label)) + \
                                                                                            reg_loss)
        #cost = (tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits = self.output, labels = self.label)) + \
                                                                                            #reg_loss) * 1/(0.01+gap_loss)
        
        #Batch Normalization
        update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
        with tf.control_dependencies(update_ops):
            optimizer = tf.train.AdamOptimizer(learning_rate=self.tflearnrate).minimize(cost, global_step = self.global_step)
            
        return optimizer, cost 
    
    def test(self):
        prediction = tf.greater(self.output, tf.constant(0.5, dtype = tf.float32))
        prediction = tf.cast(prediction, dtype = tf.float32)
        with tf.name_scope('accuracy'):
            with tf.name_scope('correct_prediction'):
                correct_prediction = tf.equal(tf.cast(prediction, dtype = tf.float32), self.label)
            with tf.name_scope('accuracy'):
                accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
                tf.summary.scalar('accuracy', accuracy)
        return prediction, accuracy
    
    def graph_classifier(self):
        curlearnrate = self.learning_rate
        step = 0 
        for epochs in range(self.epoch_nums):
            output = []
            mini_batch = random_mini_batches3(self.inputdat, self.labeldat, self.vertexdat, self.batch_size)
            curlearnrate = curlearnrate * self.decayrate 
            for dat in mini_batch:
                step = step + 1 
                _, cost, output, summary = self.sess.run([self.optimizer, self.cost, self.output, self.summary_op], 
                                                feed_dict = {self.input: dat[0], self.label: dat[1], self.vertexlabel: dat[2],\
                                                             self.mode: True, self.tflearnrate: curlearnrate})
                (self.writer).add_summary(summary, global_step = step)
            if ((epochs+1) % 50 == 0):
                
                _, errortrain = self.evaluate("train")
                output, cost, accuracy = self.sess.run([self.output, self.cost, self.accuracy], \
                        feed_dict = {self.input: self.inputdat, self.label: self.labeldat, self.vertexlabel: self.vertexdat, \
                                     self.mode: False, self.tflearnrate: curlearnrate})
                (self.saver).save(self.sess, 'checkpoints/CNN', global_step=self.global_step)
                _, errortest = self.evaluate("test")
                print("epoch", epochs + 1, "    |    ", "cost", "%.6e" % cost, "    |    ", 
                      "error train", "%.3f" % (errortrain * 100), "    |    ", "error test", "%.3f" % (errortest * 100), 
                      "   |   ", "output gap", "%.6e" % (np.max(output) - np.min(output)))
            
                #if ((epochs+1) % 200 == 0):
                #    print(output[0], output[len(output)-1])
                
    def evaluate(self, mode):
        #Get predictions
        
        if mode == "train":
            predictions = self.sess.run([self.prediction], 
                                    feed_dict = {self.input: self.inputdat, self.label: self.labeldat, self.vertexlabel: self.vertexdat,\
                                                 self.mode: False})
            predictions = np.array(predictions).reshape((self.num_eg,1))
            #predictions = predictions.astype(int)
        
            #Compute error
            error = np.sum((predictions - self.labeldat)**2)/self.num_eg
            #print("error " + mode, error * 100)
        else:
            predictions, gcn = self.sess.run([self.prediction, self.gcn], 
                                    feed_dict = {self.input: self.testdat, self.label: self.testlabeldat, self.vertexlabel: self.testvertexdat,\
                                                 self.mode: False})
            predictions = np.array(predictions).reshape((self.num_eg,1))
            #predictions = predictions.astype(int)
        
            #Compute error
            error = np.sum((predictions - self.testlabeldat)**2)/self.num_eg
            #print("error " + mode, error * 100)
            
        return predictions, error
    
    def evaluate_cluster(self):
        #Get predictions
        
        predictions, gcn = self.sess.run([self.prediction, self.gcn], 
                                    feed_dict = {self.input: self.testdat, self.label: self.testlabeldat, self.vertexlabel: self.testvertexdat,\
                                                 self.mode: False})
        print(gcn[0,0:self.inputdim,:])
        
        for i in range(10):
            graph = gcn[i,0:self.inputdim,:]
            label = self.vertexclass[i,:]
            kmeans = KMeans(n_clusters=2, random_state=0).fit(graph)
            print(label)
            print(kmeans)
        
        return None
    
    def graph_convolutional_layer(self, X, An, name, dim):
        
        AX = tf.matmul(An, X)
        btsize = tf.shape(AX)[0]
        numver = An.shape[1]
        vertex = AX.shape[2]
        
        #AX = tf.tile(tf.expand_dims(AX, 1), [1, rep, 1, 1])
        
        #print(btsize)
        #print(vertex)
        #with tf.variable_scope(name):
        W = tf.get_variable('W', [vertex, dim])
        mW = tf.tile(tf.expand_dims(W, 0), [btsize, 1, 1]) 
        
        #bW = tf.get_variable('bW', [numver, dim])
        #mbW = tf.tile(tf.expand_dims(bW, 0), [btsize, 1, 1]) 
        
        output = tf.matmul(AX,mW) 
        
        output = tf.nn.relu(output)
        #print(output.shape)
        #print(output.shape)
        return output 
    
    def gated_graph_convolutional_layer(self, X, An, name, dim):
        
        AX = tf.matmul(An, X)
        btsize = tf.shape(AX)[0]
        numver = AX.shape[1]
        vertex = AX.shape[2]
        
        #AX = tf.tile(tf.expand_dims(AX, 1), [1, rep, 1, 1])
        
        #print(btsize)
        #print(vertex)
        #with tf.variable_scope(name):
        W = tf.get_variable('W', [vertex, dim])
        mW = tf.tile(tf.expand_dims(W, 0), [btsize, 1, 1]) 
        
        Wn = tf.get_variable('Wn', [vertex, dim])
        mWn = tf.tile(tf.expand_dims(Wn, 0), [btsize, 1, 1]) 
        
        #bW = tf.get_variable('bW', [numver, dim])
        #mbW = tf.tile(tf.expand_dims(bW, 0), [btsize, 1, 1]) 
        
        output = tf.matmul(AX,mW) + tf.matmul(X,mWn) 
        
        output = tf.nn.relu(output)
        
        G = tf.get_variable('G', [vertex, dim])
        mG = tf.tile(tf.expand_dims(G, 0), [btsize, 1, 1]) 
        
        Gn = tf.get_variable('Gn', [vertex, dim])
        mGn = tf.tile(tf.expand_dims(Gn, 0), [btsize, 1, 1]) 
        
        #bG = tf.get_variable('bG', [numver, dim])
        #mbG = tf.tile(tf.expand_dims(bG, 0), [btsize, 1, 1]) 
        
        gate = tf.matmul(AX,mG) + tf.matmul(X,mGn)  
        
        gate = tf.nn.sigmoid(gate)
        
        output = tf.multiply((1-gate), X) + tf.multiply(gate, output)
        #print(output.shape)
        #print(output.shape)
        return output 
    
    #def graph_local_convolution(self, X):
    #    vertex = self.inputdim
        
    #    for i in range(vertex):
            
    #    W = tf.get_variable(name + 'W', [vertex, dim])
    #    mW = tf.tile(tf.expand_dims(W, 0), [btsize, 1, 1]) 
    #    return None"""

# %%
if  __name__ == "__main__":
    
    num_eg = 2000
    vertex = 37
    vertexdim = 20 
    inputdim = vertexdim
    
    #train ensemble 
    #data = gs.generate_ensemble([int(num_eg/2), int(num_eg/2)], vertex, [1/3, 1/2])
    #data = gs.generate_ensemble_v2_label(num_eg, vertex-1)
    data = gs.generate_ensemble_v2_label(num_eg, vertex-1)
    data = gs.augment(data)
    
    #Normalize input:
    datagraph = data["graphs"]
    for i in range(num_eg):
        curgraph = datagraph[i,:,:]
        degree = np.sum(curgraph, axis = 0)
        updategraph = 1/np.sqrt(degree) * curgraph * 1/np.sqrt(degree)
        data["graphs"][i,:,:] = updategraph 
    
    datavertex = np.random.normal(loc=1, scale=0.0, size=(num_eg, vertex, vertexdim)).astype(np.float32)
    
    #data = gs.generate_ensemble_n2v(num_eg, vertex)
    #test ensemble
    #testdata = gs.generate_ensemble([int(num_eg/2), int(num_eg/2)], vertex, [1/3, 1/2])
    testdata = gs.generate_ensemble_v2_label(num_eg, vertex-1)
    testdata = gs.augment(testdata)
    
    testdatagraph = testdata["graphs"]
    for i in range(num_eg):
        curgraph = testdatagraph[i,:,:]
        degree = np.sum(curgraph, axis = 0)
        updategraph = 1/np.sqrt(degree) * curgraph * 1/np.sqrt(degree)
        testdata["graphs"][i,:,:] = updategraph 
        
    testdatavertex = np.random.normal(loc=1, scale=0.0, size=(num_eg, vertex, vertexdim)).astype(np.float32)
    #testdata = gs.generate_ensemble_n2v(num_eg, vertex)
    #reformat 
    data["graphs"] = data["graphs"].reshape((num_eg, vertex, vertex))
    testdata["graphs"] = testdata["graphs"].reshape((num_eg, vertex, vertex))
    
    #Fully connected model 
    GCN = GCN(data["graphs"], data["labels"], data["vertex"], datavertex, testdata["graphs"], testdata["labels"], testdata["vertex"], testdatavertex, [inputdim,15,10,5,1])
    
    #Test Model 
    #FullNN.inputdat = testdata["graphs"]
    #FullNN.labeldat = testdata["labels"]
    #FullNN.trainmode = False
    #FullNN.evaluate()
# Out:
# epoch 50     |     cost 7.338668e-01     |     error train 50.000     |     error test 50.000    |    output gap 5.829334e-05
# epoch 100     |     cost 7.311763e-01     |     error train 50.000     |     error test 50.000    |    output gap 2.098352e-03
# epoch 150     |     cost 7.270502e-01     |     error train 50.000     |     error test 50.000    |    output gap 1.925088e-03
# epoch 200     |     cost 7.262408e-01     |     error train 50.000     |     error test 50.000    |    output gap 0.000000e+00
# epoch 250     |     cost 7.254982e-01     |     error train 50.000     |     error test 50.000    |    output gap 1.600933e-02
# epoch 300     |     cost 7.206981e-01     |     error train 50.000     |     error test 50.000    |    output gap 3.334232e-01
# epoch 350     |     cost 7.774249e-01     |     error train 50.000     |     error test 50.000    |    output gap 1.962185e-02
# epoch 400     |     cost 8.130676e-01     |     error train 50.000     |     error test 50.000    |    output gap 3.676414e-04
# epoch 450     |     cost 8.258938e-01     |     error train 50.000     |     error test 50.000    |    output gap 6.526709e-05
# epoch 500     |     cost 8.316123e-01     |     error train 50.000     |     error test 50.000    |    output gap 1.430511e-05
# epoch 550     |     cost 8.335745e-01     |     error train 50.000     |     error test 50.000    |    output gap 5.364418e-07
# epoch 600     |     cost 8.358971e-01     |     error train 50.000     |     error test 50.000    |    output gap 5.785167e-03
# epoch 650     |     cost 8.366971e-01     |     error train 50.000     |     error test 50.000    |    output gap 1.180589e-02
# epoch 700     |     cost 8.355188e-01     |     error train 50.000     |     error test 50.000    |    output gap 1.107943e-02
# epoch 750     |     cost 8.347705e-01     |     error train 50.000     |     error test 50.000    |    output gap 1.164681e-02
# epoch 800     |     cost 8.339903e-01     |     error train 50.000     |     error test 50.000    |    output gap 1.131588e-02
# epoch 850     |     cost 7.880680e-01     |     error train 42.500     |     error test 42.300    |    output gap 9.333570e-01
# epoch 900     |     cost 6.744280e-01     |     error train 22.350     |     error test 22.450    |    output gap 9.323854e-01
# epoch 950     |     cost 5.715898e-01     |     error train 4.150     |     error test 5.050    |    output gap 9.315146e-01
# epoch 1000     |     cost 5.660474e-01     |     error train 3.700     |     error test 4.450    |    output gap 9.312186e-01
# epoch 1050     |     cost 5.685163e-01     |     error train 3.950     |     error test 4.800    |    output gap 9.312897e-01
# epoch 1100     |     cost 5.646132e-01     |     error train 3.300     |     error test 4.300    |    output gap 9.312325e-01
# epoch 1150     |     cost 5.613872e-01     |     error train 3.100     |     error test 3.900    |    output gap 9.310008e-01
# epoch 1200     |     cost 5.610311e-01     |     error train 3.100     |     error test 4.050    |    output gap 9.309473e-01
# epoch 1250     |     cost 5.611221e-01     |     error train 3.100     |     error test 4.150    |    output gap 9.309853e-01
# epoch 1300     |     cost 5.612109e-01     |     error train 3.050     |     error test 4.000    |    output gap 9.310374e-01
# epoch 1350     |     cost 5.611592e-01     |     error train 3.100     |     error test 4.150    |    output gap 9.310178e-01
# epoch 1400     |     cost 5.611633e-01     |     error train 3.050     |     error test 4.050    |    output gap 9.310317e-01
# epoch 1450     |     cost 5.612026e-01     |     error train 3.050     |     error test 4.000    |    output gap 9.310235e-01
# epoch 1500     |     cost 5.612112e-01     |     error train 3.050     |     error test 4.000    |    output gap 9.310225e-01
# epoch 1550     |     cost 5.612325e-01     |     error train 3.000     |     error test 4.050    |    output gap 9.310122e-01
# epoch 1600     |     cost 5.612270e-01     |     error train 3.000     |     error test 4.050    |    output gap 9.310578e-01
# epoch 1650     |     cost 5.612223e-01     |     error train 3.000     |     error test 4.050    |    output gap 9.310415e-01
# epoch 1700     |     cost 5.612206e-01     |     error train 3.000     |     error test 4.050    |    output gap 9.310188e-01
# epoch 1750     |     cost 5.612251e-01     |     error train 3.000     |     error test 4.050    |    output gap 9.310437e-01
# epoch 1800     |     cost 5.612169e-01     |     error train 3.000     |     error test 4.050    |    output gap 9.310624e-01
# epoch 1850     |     cost 5.612155e-01     |     error train 3.000     |     error test 4.050    |    output gap 9.310762e-01
# epoch 1900     |     cost 5.612118e-01     |     error train 3.050     |     error test 4.000    |    output gap 9.310422e-01
# epoch 1950     |     cost 5.612155e-01     |     error train 3.050     |     error test 4.000    |    output gap 9.310046e-01
# epoch 2000     |     cost 5.612264e-01     |     error train 3.000     |     error test 4.050    |    output gap 9.310298e-01

# %%
class FullNN:
    
    def __init__(self, inputdat, labeldat, testdat, testlabeldat, layer_dims, decayrate = 0.99,
                 l2reg = 1e-2, learning_rate = 0.008, batch_size = 128, epoch_nums = 15000):
        
        #Data
        self.inputdat = inputdat
        self.labeldat = labeldat
        self.testdat = testdat
        self.testlabeldat = testlabeldat
        self.num_eg = inputdat.shape[0]
        
        #Hyperparameters
        self.layer_dims = layer_dims
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.epoch_nums = epoch_nums
        self.l2reg = l2reg  
        self.decayrate = decayrate 
        
        #Initialize
        tf.reset_default_graph()
        self.initdata()
        
        #Create graph
        self.output = self.model()
        self.optimizer, self.cost = self.train()
        self.prediction, self.accuracy = self.test()
        self.summary_op = self.create_summaries()
        
        #Run Tensorflow
        config = tf.ConfigProto(allow_soft_placement = True, log_device_placement = True, device_count = {'GPU': 1})
        self.sess = tf.Session(config = config)
        init = tf.group(tf.global_variables_initializer(), tf.local_variables_initializer())
        self.sess.run(init)
        
        #Tensorboard setup
        self.writer = tf.summary.FileWriter('./FullNNSave',  (self.sess).graph)
        
        #Train model 
        self.graph_classifier()
        self.prediction_num, self.error_num = self.evaluate("train") 
        
    def  create_summaries(self):
        with tf.name_scope("summaries"):
            tf.summary.scalar("loss", self.cost)
            tf.summary.scalar("accuracy", self.accuracy)
            tf.summary.histogram("histogram_loss", self.cost)
            summary_op = tf.summary.merge_all()
        return summary_op
    
    def initdata(self):
        self.tflearnrate = tf.placeholder(tf.float32, name = "learnrate")
        self.mode = tf.placeholder(tf.bool, name = "mode")
        self.input = tf.placeholder(tf.float32, shape = [None, self.layer_dims[0]], name = "input")
        self.label = tf.placeholder(tf.float32, shape = [None, 1], name = "label")

    
    def model(self):
        layer_dims = self.layer_dims
        layers = {}
        layers[0] = self.input
        for i in range(len(layer_dims)-1):
            if (i < len(layer_dims) - 2):
                scope = 'layers' + str(i+1)
                with tf.variable_scope(scope):
                    #layers[i+1] = tf.layers.dense(units = layer_dims[i+1], activation = tf.nn.relu, inputs = layers[i])
                    layers[i+1] = tf.contrib.layers.fully_connected(num_outputs = layer_dims[i+1], \
                                                        activation_fn = None, inputs = layers[i], scope = 'dense')
                    layers[i+1] = tf.contrib.layers.batch_norm(layers[i+1], is_training = self.mode, scope = 'batchnorm')
                    layers[i+1] = tf.nn.relu(layers[i+1], 'relu')
            else:
                scope = 'layers' + str(i+1)
                with tf.variable_scope(scope):
                    layers[len(layer_dims)-1] = tf.layers.dense(units = layer_dims[len(layer_dims)-1], \
                                                    activation = tf.nn.sigmoid, inputs = layers[len(layer_dims)-2])
        
        output = layers[len(layer_dims)-1]
        return output 
    
    def train(self):
        #Saver for data 
        self.saver = tf.train.Saver()
        self.global_step = tf.Variable(0, dtype = tf.int32, trainable = False, name = 'global_step')
        
        #Define cost 
        reg_loss = self.l2reg * sum(tf.nn.l2_loss(tf_var) for tf_var in tf.trainable_variables()) 
        cost = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits = self.output, labels = self.label)) + \
                                                                                                            reg_loss 
        
        #Batch Normalization
        update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
        with tf.control_dependencies(update_ops):
            optimizer = tf.train.AdamOptimizer(learning_rate=self.tflearnrate).minimize(cost, global_step = self.global_step)
            
        return optimizer, cost 
    
    def test(self):
        prediction = tf.greater(self.output, tf.constant(0.5, dtype = tf.float32))
        with tf.name_scope('accuracy'):
            with tf.name_scope('correct_prediction'):
                correct_prediction = tf.equal(tf.cast(prediction, dtype = tf.float32), self.label)
            with tf.name_scope('accuracy'):
                accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
                tf.summary.scalar('accuracy', accuracy)
        return prediction, accuracy
    
    def graph_classifier(self):
        curlearnrate = self.learning_rate
        step = 0 
        for epochs in range(self.epoch_nums):
            output = []
            mini_batch = random_mini_batches2(self.inputdat, self.labeldat, self.batch_size)
            curlearnrate = curlearnrate * self.decayrate 
            for dat in mini_batch:
                step = step + 1 
                _, cost, output, summary = self.sess.run([self.optimizer, self.cost, self.output, self.summary_op], 
                                                feed_dict = {self.input: dat[0], self.label: dat[1], \
                                                             self.mode: True, self.tflearnrate: curlearnrate})
                (self.writer).add_summary(summary, global_step = step)
            if (epochs % 100 == 0):
                _, errortrain = self.evaluate("train")
                cost, accuracy = self.sess.run([self.cost, self.accuracy], \
                        feed_dict = {self.input: self.inputdat, self.label: self.labeldat, \
                                     self.mode: False, self.tflearnrate: curlearnrate})
                (self.saver).save(self.sess, 'checkpoints/CNN', global_step=self.global_step)
                _, errortest = self.evaluate("test")
                print("epoch", epochs, "    |    ", "cost", "%.6e" % cost, "    |    ", 
                      "error train", "%.3f" % (errortrain * 100), "    |    ", "error test", "%.3f" % (errortest * 100))
        
    def evaluate(self, mode):
        #Get predictions
        if mode == "train":
            predictions = self.sess.run([self.prediction], 
                                    feed_dict = {self.input: self.inputdat, self.label: self.labeldat, \
                                                 self.mode: False})
        else:
            predictions = self.sess.run([self.prediction], 
                                    feed_dict = {self.input: self.testdat, self.label: self.testlabeldat, \
                                                 self.mode: False})
        predictions = np.array(predictions).reshape((self.num_eg,1))
        predictions = predictions.astype(int)
        
        #Compute error
        error = np.sum((predictions - self.labeldat)**2)/self.num_eg
        #print("error " + mode, error * 100)
        
        return predictions, error

# %%
num_eg = 4000
vertex = 37

inputdim = 20

#data = gs.generate_ensemble([int(num_eg/2), int(num_eg/2)], vertex-1, [1/3, 1/2])
#testdata = gs.generate_ensemble([int(num_eg/2), int(num_eg/2)], vertex-1, [1/3, 1/2])
data = gs.generate_ensemble_v3(num_eg, vertex-1)
testdata = gs.generate_ensemble_v3(num_eg, vertex-1)
data = gs.augment(data)
testdata = gs.augment(testdata)
datagraph = data["graphs"]
for i in range(num_eg):
    curgraph = datagraph[i,:,:]
    degree = np.sum(curgraph, axis = 0)
    updategraph = 1/np.sqrt(degree) * curgraph * 1/np.sqrt(degree)
    data["graphs"][i,:,:] = updategraph 
testdatagraph = testdata["graphs"]
for i in range(num_eg):
    curgraph = testdatagraph[i,:,:]
    degree = np.sum(curgraph, axis = 0)
    updategraph = 1/np.sqrt(degree) * curgraph * 1/np.sqrt(degree)
    testdata["graphs"][i,:,:] = updategraph 
datavertex = np.random.normal(loc=1, scale=0.0, size=(num_eg, vertex, vertexdim)).astype(np.float32)
testdatavertex = np.random.normal(loc=1, scale=0.0, size=(num_eg, vertex, vertexdim)).astype(np.float32)
#reformat 
GCN.testdat = data["graphs"]
GCN.testlabeldat = data["labels"]
GCN.testvertexdat = datavertex
gcndata = GCN.sess.run([GCN.gcn], feed_dict = {GCN.input: GCN.testdat, GCN.label: GCN.testlabeldat, GCN.vertexlabel: GCN.testvertexdat,\
                                                 GCN.mode: False})
gcndata = np.asarray(gcndata)
print(gcndata[:,0,vertex-1,:])


data["graphs"] = gcndata[:,:,vertex-1,:].reshape(num_eg, -1)

GCN.testdat = testdata["graphs"]
GCN.testlabeldat = testdata["labels"]
GCN.testertexdat = testdatavertex
gcntestdata = GCN.sess.run([GCN.gcn], feed_dict = {GCN.input: GCN.testdat, GCN.label: GCN.testlabeldat, GCN.vertexlabel: GCN.testvertexdat,\
                                                 GCN.mode: False})
gcntestdata = np.asarray(gcntestdata)
testdata["graphs"] = gcntestdata[:,:,(vertex-1),:].reshape((num_eg, -1))



#Fully connected model 
FullNN = FullNN(data["graphs"], data["labels"], testdata["graphs"], testdata["labels"], [inputdim,15,10,5,1])

#Test Model 
#FullNN.inputdat = testdata["graphs"]
#FullNN.labeldat = testdata["labels"]
#FullNN.trainmode = False
#FullNN.evaluate()
# Out:
# [[4.221077  3.0878417 3.0301948 0.6495284 3.2611458 5.3808627 3.324382
#   1.6323758 2.6914144 4.5126734 3.1303089 3.9042525 3.115565  3.1139085
#   3.7151766 4.076896  3.3328636 4.5396385 3.9867606 0.8919892]]
# epoch 0     |     cost 7.464005e-01     |     error train 30.900     |     error test 30.450
# epoch 100     |     cost 7.024938e-01     |     error train 45.675     |     error test 46.550
# epoch 200     |     cost 8.362141e-01     |     error train 50.000     |     error test 50.000
# epoch 300     |     cost 5.965539e-01     |     error train 14.100     |     error test 13.875
# epoch 400     |     cost 6.904902e-01     |     error train 26.875     |     error test 27.200
# epoch 500     |     cost 5.957232e-01     |     error train 9.650     |     error test 9.125
# epoch 600     |     cost 5.845035e-01     |     error train 10.975     |     error test 10.925
# epoch 700     |     cost 5.763803e-01     |     error train 7.000     |     error test 6.250
# epoch 800     |     cost 5.759792e-01     |     error train 7.100     |     error test 6.425
# epoch 900     |     cost 5.756148e-01     |     error train 7.100     |     error test 6.550
# epoch 1000     |     cost 5.755301e-01     |     error train 7.000     |     error test 6.650
# epoch 1100     |     cost 5.754911e-01     |     error train 7.100     |     error test 6.700
# epoch 1200     |     cost 5.754985e-01     |     error train 7.075     |     error test 6.650
# epoch 1300     |     cost 5.755076e-01     |     error train 7.050     |     error test 6.650
# epoch 1400     |     cost 5.755146e-01     |     error train 7.050     |     error test 6.650
# epoch 1500     |     cost 5.755025e-01     |     error train 7.050     |     error test 6.650
# epoch 1600     |     cost 5.755173e-01     |     error train 7.050     |     error test 6.650
# epoch 1700     |     cost 5.755066e-01     |     error train 7.050     |     error test 6.650
# epoch 1800     |     cost 5.755042e-01     |     error train 7.050     |     error test 6.650
# epoch 1900     |     cost 5.755090e-01     |     error train 7.050     |     error test 6.650
# epoch 2000     |     cost 5.755097e-01     |     error train 7.050     |     error test 6.650
# epoch 2100     |     cost 5.755041e-01     |     error train 7.025     |     error test 6.650
# epoch 2200     |     cost 5.755099e-01     |     error train 7.050     |     error test 6.650
# epoch 2300     |     cost 5.755043e-01     |     error train 7.050     |     error test 6.650
# epoch 2400     |     cost 5.755171e-01     |     error train 7.050     |     error test 6.650
# epoch 2500     |     cost 5.755049e-01     |     error train 7.050     |     error test 6.650
# epoch 2600     |     cost 5.755015e-01     |     error train 7.050     |     error test 6.650
# epoch 2700     |     cost 5.754991e-01     |     error train 7.075     |     error test 6.650
# epoch 2800     |     cost 5.755096e-01     |     error train 7.050     |     error test 6.650
# epoch 2900     |     cost 5.755175e-01     |     error train 7.050     |     error test 6.650
# epoch 3000     |     cost 5.755128e-01     |     error train 7.050     |     error test 6.650
# epoch 3100     |     cost 5.755066e-01     |     error train 7.075     |     error test 6.650
# epoch 3200     |     cost 5.755107e-01     |     error train 7.025     |     error test 6.650
# epoch 3300     |     cost 5.755185e-01     |     error train 7.050     |     error test 6.650
# epoch 3400     |     cost 5.755144e-01     |     error train 7.050     |     error test 6.650
# epoch 3500     |     cost 5.755153e-01     |     error train 7.050     |     error test 6.650
# epoch 3600     |     cost 5.755047e-01     |     error train 7.050     |     error test 6.650
# epoch 3700     |     cost 5.755185e-01     |     error train 7.050     |     error test 6.650
# epoch 3800     |     cost 5.755213e-01     |     error train 7.050     |     error test 6.650
# epoch 3900     |     cost 5.755014e-01     |     error train 7.050     |     error test 6.650
# epoch 4000     |     cost 5.755073e-01     |     error train 7.050     |     error test 6.650
# epoch 4100     |     cost 5.755048e-01     |     error train 7.050     |     error test 6.650
# epoch 4200     |     cost 5.755128e-01     |     error train 7.050     |     error test 6.650
# epoch 4300     |     cost 5.755038e-01     |     error train 7.050     |     error test 6.650
# epoch 4400     |     cost 5.755129e-01     |     error train 7.050     |     error test 6.650
# epoch 4500     |     cost 5.755001e-01     |     error train 7.025     |     error test 6.650
# epoch 4600     |     cost 5.755033e-01     |     error train 7.050     |     error test 6.650
# epoch 4700     |     cost 5.755072e-01     |     error train 7.050     |     error test 6.650
# epoch 4800     |     cost 5.755113e-01     |     error train 7.050     |     error test 6.650
# epoch 4900     |     cost 5.755126e-01     |     error train 7.025     |     error test 6.650
# epoch 5000     |     cost 5.755012e-01     |     error train 7.050     |     error test 6.650
# epoch 5100     |     cost 5.755168e-01     |     error train 7.050     |     error test 6.650
# epoch 5200     |     cost 5.755067e-01     |     error train 7.050     |     error test 6.650
# epoch 5300     |     cost 5.755119e-01     |     error train 7.025     |     error test 6.650
# epoch 5400     |     cost 5.755034e-01     |     error train 7.025     |     error test 6.650
# epoch 5500     |     cost 5.755143e-01     |     error train 7.050     |     error test 6.650
# epoch 5600     |     cost 5.754975e-01     |     error train 7.050     |     error test 6.650
# epoch 5700     |     cost 5.755073e-01     |     error train 7.025     |     error test 6.650
# epoch 5800     |     cost 5.754979e-01     |     error train 7.050     |     error test 6.650
# epoch 5900     |     cost 5.755220e-01     |     error train 7.025     |     error test 6.650
# epoch 6000     |     cost 5.755042e-01     |     error train 7.050     |     error test 6.650
# epoch 6100     |     cost 5.755031e-01     |     error train 7.050     |     error test 6.650
# epoch 6200     |     cost 5.755011e-01     |     error train 7.050     |     error test 6.650
# epoch 6300     |     cost 5.755014e-01     |     error train 7.050     |     error test 6.650
# epoch 6400     |     cost 5.755121e-01     |     error train 7.050     |     error test 6.650
# epoch 6500     |     cost 5.755090e-01     |     error train 7.050     |     error test 6.650
# epoch 6600     |     cost 5.754989e-01     |     error train 7.050     |     error test 6.650
# epoch 6700     |     cost 5.755020e-01     |     error train 7.050     |     error test 6.650
# epoch 6800     |     cost 5.755141e-01     |     error train 7.050     |     error test 6.650
# epoch 6900     |     cost 5.755077e-01     |     error train 7.050     |     error test 6.650
# epoch 7000     |     cost 5.754990e-01     |     error train 7.050     |     error test 6.650
# epoch 7100     |     cost 5.755135e-01     |     error train 7.050     |     error test 6.650
# epoch 7200     |     cost 5.754983e-01     |     error train 7.050     |     error test 6.650
# epoch 7300     |     cost 5.755093e-01     |     error train 7.050     |     error test 6.650
# epoch 7400     |     cost 5.755051e-01     |     error train 7.050     |     error test 6.650
# epoch 7500     |     cost 5.755011e-01     |     error train 7.050     |     error test 6.650
# epoch 7600     |     cost 5.755152e-01     |     error train 7.050     |     error test 6.650
# epoch 7700     |     cost 5.755137e-01     |     error train 7.050     |     error test 6.650
# epoch 7800     |     cost 5.755061e-01     |     error train 7.050     |     error test 6.650
# epoch 7900     |     cost 5.755048e-01     |     error train 7.050     |     error test 6.650
# epoch 8000     |     cost 5.755166e-01     |     error train 7.050     |     error test 6.650
# epoch 8100     |     cost 5.755072e-01     |     error train 7.050     |     error test 6.650
# epoch 8200     |     cost 5.755078e-01     |     error train 7.050     |     error test 6.650
# epoch 8300     |     cost 5.755014e-01     |     error train 7.050     |     error test 6.650
# epoch 8400     |     cost 5.755180e-01     |     error train 7.050     |     error test 6.650
# epoch 8500     |     cost 5.755164e-01     |     error train 7.050     |     error test 6.650
# epoch 8600     |     cost 5.755160e-01     |     error train 7.050     |     error test 6.650
# epoch 8700     |     cost 5.755177e-01     |     error train 7.050     |     error test 6.650
# epoch 8800     |     cost 5.755125e-01     |     error train 7.050     |     error test 6.650
# epoch 8900     |     cost 5.755102e-01     |     error train 7.050     |     error test 6.650
# epoch 9000     |     cost 5.755055e-01     |     error train 7.050     |     error test 6.650
# epoch 9100     |     cost 5.754988e-01     |     error train 7.025     |     error test 6.650
# epoch 9200     |     cost 5.755079e-01     |     error train 7.050     |     error test 6.650
# epoch 9300     |     cost 5.755125e-01     |     error train 7.050     |     error test 6.650
# epoch 9400     |     cost 5.755146e-01     |     error train 7.050     |     error test 6.650
